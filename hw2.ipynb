# %% [markdown]
# Задания к уроку 2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import numpy as np

# %% [markdown]
# #### Задание 1

# %%
#Сумма (10,10,0)
x=np.array([20,50,10])
y=np.array([0,0,-10])

sum = np.add(x,y)
sk=x@x
sx=y@y
s = np.sqrt(sk)
s1=np.sqrt(sx)
print(sum)
print(s,s1)
# Out:
# [20 50  0]
# 54.772255750516614 10.0

# %% [markdown]
# #### Задание 2

# %%
x = np.linspace(-5, 5, 21)
y = 3*x+1
y2=(-1/3)*x+1
plt.plot(x,y2)
plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.grid('True')
plt.show()

# %%
#### потому что оси X и Y не приведенны к одним значениям, т.е. имеют разный масштаб

# %% [markdown]
# #### Задание 3

# %%
#Гипербола
x = []
y1 = []
y2 = []
a = 1
b = 1
for i in range(1000):
    x1= i/100
    x.append(x1)
    y1.append(b*math.sqrt(1+x1**2/a**2))
    y2.append(-b*math.sqrt(1+x1**2/a**2))
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
a = 1
b = 1
x = np.linspace(-10, 20, 100)
f = lambda x: b*np.sqrt(1+x**2/a**2)
plt.plot(x, f(x))
plt.plot(x, - f(x))

# %% [markdown]
# #### Элипс

# %%
a = 3
b = 2
x = np.linspace(-5.0, 5.0, 100)
y = np.linspace(-5.0, 5.0, 100)
X, Y = np.meshgrid(x,y)
F = X**2/a**2 + Y**2/b**2 - 1
plt.contour(X,Y,F,[0])
plt.show()

# %%
a=1
b=2
x = np.linspace(-4, 4, 1000)
y = np.sqrt(b*np.sqrt(1-x**2/a**2))
plt.plot(x,y)
plt.plot(x,-y)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in sqrt
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Окружность

# %%
r = 1
x = np.linspace(-1.0, 1.0, 100)
y = np.linspace(-1.0, 1.0, 100)
X, Y = np.meshgrid(x,y)
F = X**2 + Y**2 - r**2
plt.contour(X,Y,F,[0])
plt.show()

# %%
r = 8
x = np.linspace(-r,r,1000)
y = np.sqrt(-x**2+r**2)
plt.plot(x, y,'b')
plt.plot(x,-y,'b')
plt.gca().set_aspect('equal')
plt.show()

# %%
r=1
x = np.linspace(-1, 1, 10000)
y = np.sqrt(-x**2 + r**2)
plt.plot(x, y)
plt.plot(x, -y)
plt.show()

# %%
# theta goes from 0 to 2pi
theta = np.linspace(0, 2*np.pi, 100)

# the radius of the circle
r = np.sqrt(0.6)

# compute x1 and x2
x1 = r*np.cos(theta)
x2 = r*np.sin(theta)

# create the figure
fig, ax = plt.subplots(1)
ax.plot(x1, x2)
ax.set_aspect(1)
plt.show()

# %% [markdown]
# #### Задание 4

# %% [markdown]
# 1) k*A*x + k*B*y + k*C*z = 0
# 2) Прямая принадлежит плоскости если две ее точки принадлежат плоскости, т. е. есть если точки (x1,y1,z1) и (x2,y2,z2) принадлежат пдоскости A1x+B1y+C1z+D=0

# %% [markdown]
# #### Задание 5

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5,5,0.5)
Y = np.arange(-5,5, 0.5)
X,Y = np.meshgrid(X,Y)
Z = 2*X+5*Y
ax.plot_surface(X,Y,Z)
k=0.5
ax.plot_surface(k*X,k*Y, Z)
k=2
ax.plot_surface(k*X,k*Y, Z)

# %%
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5,5,0.5)
Y = np.arange(-5,5, 0.5)
X,Y = np.meshgrid(X,Y)
Z = X**2-Y**2
ax.plot_wireframe(X, Y, Z)

# %%
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5,5,0.5)
Y = np.arange(-5,5, 0.5)
X,Y = np.meshgrid(X,Y)
Z = X**3-Y**2
ax.plot_wireframe(X, Y, Z)

# %%
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5,5,0.5)
Y = np.arange(-5,5, 0.5)
X,Y = np.meshgrid(X,Y)
Z = np.sqrt(X**2-Y**2)
ax.plot_wireframe(X, Y, Z)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in sqrt

# %% [markdown]
# Задания к уроку 3

# %% [markdown]
# #### Задание 1

# %%
x = np.linspace(-np.pi, np.pi, 100)
k=2
a=3
b=4
plt.plot(x, k*cos(x-a) + b)
k=1
a=1
b=1
plt.plot(x, k*cos(x-a) + b)
k=-2
a=-3
b=-4
plt.plot(x, k*cos(x-a) + b)

# %% [markdown]
# Задание 2 - см. файл

# %% [markdown]
# #### Заданее 3

# %%
#1
r=1
a = np.pi/2
B = [X,Y]
X = r*np.cos(a)
Y = r*np.sin(a)
print(B)
# Out:
# [6.123233995736766e-17, 1.0]

# %%
x = r * math.cos(math.radians(theta))
y = r * math.sin(math.radians(theta))

# %%
#2
r=1
x = np.linspace(-1, 1, 100)
y = np.sqrt(-x**2 + r**2)
plt.polar(x, y)
plt.polar(x, -y)
plt.show()

# %%
x = np.linspace(-5, 5, 210)
y = 3*x+1
plt.polar(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.grid('True')
plt.show()

# %% [markdown]
# #### Задание 4

# %%
#1
x = np.linspace(-5, 5, 500)
plt.plot(x, x**2-1)
plt.plot(x, (np.exp(x)+x-1)/x)
plt.xlabel('X')
plt.ylabel('Y')
plt.grid('True')
plt.show()

# %%
from scipy.optimize import fsolve

def aqution(p):
    x, y = p
    return(y-x**2+1, np.exp(x) +x*(1-y)-1)

x1,y1 = fsolve(aqution,(1, 1))
print(x1,y1)
# Out:
# 1.0812694402316097e-13 -0.999999999999867

# %%
#2
x = np.linspace(-100, 100, 100)
plt.plot(x, x**2-1)
plt.plot(x, ((np.exp(x)+x-1)/x)>0)
plt.xlabel('X')
plt.ylabel('Y')
plt.grid('True')
plt.show()
